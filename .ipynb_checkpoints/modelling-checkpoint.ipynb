# %%
# ESTOY ENAMORAO DE PEDRO SANCHEZ, CONSUMO de combustible

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression, GammaRegressor

# %%
df = pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#    engine_cc  weight_kg  transmission  fuel_consumption
# 0       1600       1180             0               6.9
# 1       1800       1250             1               7.8
# 2       2000       1320             1               8.3
# 3       1400       1100             0               6.2
# 4       2200       1400             1               9.1

# %%
sns.histplot(df['fuel_consumption'],color="purple", bins=30)
# Out:
# <Axes: xlabel='fuel_consumption', ylabel='Count'>

# %%
plt.hist(df['engine_cc'], bins=30)
# Out:
# (array([3., 3., 3., 3., 4., 3., 3., 3., 4., 3., 3., 3., 4., 3., 3., 3., 4.,
#         3., 3., 3., 3., 3., 4., 0., 3., 3., 4., 3., 1., 3.]),
#  array([1200., 1250., 1300., 1350., 1400., 1450., 1500., 1550., 1600.,
#         1650., 1700., 1750., 1800., 1850., 1900., 1950., 2000., 2050.,
#         2100., 2150., 2200., 2250., 2300., 2350., 2400., 2450., 2500.,
#         2550., 2600., 2650., 2700.]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(df['weight_kg'],color="purple", bins=30)
# Out:
# (array([3., 2., 1., 2., 2., 4., 4., 4., 4., 3., 5., 3., 4., 4., 3., 3., 3.,
#         3., 2., 3., 5., 2., 3., 2., 3., 5., 3., 3., 0., 3.]),
#  array([ 970.,  991., 1012., 1033., 1054., 1075., 1096., 1117., 1138.,
#         1159., 1180., 1201., 1222., 1243., 1264., 1285., 1306., 1327.,
#         1348., 1369., 1390., 1411., 1432., 1453., 1474., 1495., 1516.,
#         1537., 1558., 1579., 1600.]),
#  <BarContainer object of 30 artists>)
