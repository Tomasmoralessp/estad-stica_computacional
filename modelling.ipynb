# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression, GammaRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#    engine_cc  weight_kg  transmission  fuel_consumption
# 0       1600       1180             0               6.9
# 1       1800       1250             1               7.8
# 2       2000       1320             1               8.3
# 3       1400       1100             0               6.2
# 4       2200       1400             1               9.1

# %%
sns.histplot(df['fuel_consumption'],color="purple", bins=30)
# Out:
# <Axes: xlabel='fuel_consumption', ylabel='Count'>

# %%
sns.histplot(df['engine_cc'], bins=30)
# Out:
# <Axes: xlabel='engine_cc', ylabel='Count'>

# %%
sns.histplot(df['weight_kg'], bins=30)
# Out:
# <Axes: xlabel='weight_kg', ylabel='Count'>

# %%
X = df.drop('fuel_consumption', axis=1)
X
# Out:
#     engine_cc  weight_kg  transmission
# 0        1600       1180             0
# 1        1800       1250             1
# 2        2000       1320             1
# 3        1400       1100             0
# 4        2200       1400             1
# ..        ...        ...           ...
# 86       1800       1220             1
# 87       2000       1300             1
# 88       1400       1080             0
# 89       2300       1450             1
# 90       2500       1530             1
#
# [91 rows x 3 columns]

# %%
y = df['fuel_consumption']
y
# Out:
# 0      6.9
# 1      7.8
# 2      8.3
# 3      6.2
# 4      9.1
#       ...
# 86     7.6
# 87     8.3
# 88     6.0
# 89     9.4
# 90    10.2
# Name: fuel_consumption, Length: 91, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=42)

# %%
plt.plot(df['engine_cc'], df['fuel_consumption'])

# %%
plt.plot(df['weight_kg'], df['fuel_consumption'])

# %%
plt.boxplot([
    df[df['transmission']==1]['fuel_consumption'],
    df[df['transmission']==0]['fuel_consumption'],
], tick_labels=['Manual', 'Automatic'])
plt.ylabel("Fuel consumption")
# Out:
# Text(0, 0.5, 'Fuel consumption')
